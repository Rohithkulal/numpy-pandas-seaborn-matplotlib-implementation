# %%
import pandas as pd
data=pd.read_csv("finance_data.csv")

# %%
data
# Out:
#           Date    Open    High     Low   Close      Revenue    Volume  Price
# 0   12/31/2015  149000  149000  131000  133000  107848.7734  11288332  23000
# 1    1/31/2016  132000  153000  126500  147500  119606.7188  10251020  23000
# 2    2/29/2016  147500  159500  143500  152500  123661.1953  10301411  23000
# 3    3/31/2016  152500  155000  142000  143500  116363.1484   7926098  23000
# 4    4/30/2016  142000  144000  131500  139500  113119.5859   9731425  23000
# ..         ...     ...     ...     ...     ...          ...       ...    ...
# 88   4/30/2023  198500  211500  197400  200000  198543.6875  12759654  23000
# 89   5/31/2023  199800  209000  194000  206500  204996.3594  11549575  23000
# 90   6/30/2023  207500  210000  194000  196000  196000.0000  13134828  23000
# 91   7/31/2023  195200  199600  182600  185400  185400.0000   8869753  23000
# 92   8/29/2023       0       0       0  186700  186700.0000         0  23000
#
# [93 rows x 8 columns]

# %% [markdown]
# # data cleaning

# %%
clean = data.dropna()
print(data.to_string())
# Out:
#           Date    Open    High     Low   Close       Revenue    Volume  Price
# 0   12/31/2015  149000  149000  131000  133000  107848.77340  11288332  23000
# 1    1/31/2016  132000  153000  126500  147500  119606.71880  10251020  23000
# 2    2/29/2016  147500  159500  143500  152500  123661.19530  10301411  23000
# 3    3/31/2016  152500  155000  142000  143500  116363.14840   7926098  23000
# 4    4/30/2016  142000  144000  131500  139500  113119.58590   9731425  23000
# 5    5/31/2016  137500  144000  133500  135500  109876.02340  12447763  23000
# 6    6/30/2016  136500  139500  128500  132000  107813.53130  12173772  23000
# 7    7/31/2016  132500  138000  129500  133000  108630.29690  10540385  23000
# 8    8/31/2016  133000  142000  131500  135500  110672.22660  10375055  23000
# 9    9/30/2016  135500  141500  131000  140000  114347.67970   9719714  23000
# 10  10/31/2016  141000  141500  129000  133000  108630.29690  10564720  23000
# ...

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 88    False
# 89    False
# 90    False
# 91    False
# 92    False
# Length: 93, dtype: bool

# %%
data.describe()
# Out:
#                 Open           High            Low          Close  \
# count      93.000000      93.000000      93.000000      93.000000
# mean   156364.516129  167281.720430  147043.010753  158644.086022
# std     38617.822663   41876.261684   37453.859724   35072.277738
# min         0.000000       0.000000       0.000000   88700.000000
# 25%    132000.000000  139500.000000  123500.000000  133000.000000
# 50%    150500.000000  163000.000000  142500.000000  152500.000000
# 75%    183000.000000  191500.000000  172000.000000  185400.000000
# max    238500.000000  289000.000000  232000.000000  239500.000000
#
#              Revenue        Volume    Price
# count      93.000000  9.300000e+01     93.0
# mean   143115.643237  1.735138e+07  23000.0
# std     37644.172801  1.470903e+07      0.0
# min     81033.460940  0.000000e+00  23000.0
# 25%    112736.117200  1.054038e+07  23000.0
# 50%    130935.726600  1.245111e+07  23000.0
# 75%    176678.765600  1.689256e+07  23000.0
# ...

# %% [markdown]
# # mean

# %%
data['Profit'] = data['Close'] - data['Open']
mean = data['Profit'].mean()
print('mean:',mean)
# Out:
# mean: 2279.569892473118

# %% [markdown]
# # median

# %%
median = data['Profit'].median()
print('median:',median)
# Out:
# median: 500.0

# %% [markdown]
# # Standard Deviation

# %%
std = data['Profit'].std()
print('Standard Deviation:',std)
# Out:
# Standard Deviation: 23471.50705198236

# %% [markdown]
# # Maximum

# %%
max = data['Profit'].max()
print('Maximum:',max)
# Out:
# Maximum: 186700

# %% [markdown]
# # Minimum

# %%
min = data['Profit'].min()
print('Minimum:',min)
# Out:
# Minimum: -27300

# %%
data.head()
# Out:
#          Date    Open    High     Low   Close      Revenue    Volume  Price  \
# 0  12/31/2015  149000  149000  131000  133000  107848.7734  11288332  23000
# 1   1/31/2016  132000  153000  126500  147500  119606.7188  10251020  23000
# 2   2/29/2016  147500  159500  143500  152500  123661.1953  10301411  23000
# 3   3/31/2016  152500  155000  142000  143500  116363.1484   7926098  23000
# 4   4/30/2016  142000  144000  131500  139500  113119.5859   9731425  23000
#
#    Profit
# 0  -16000
# 1   15500
# 2    5000
# 3   -9000
# 4   -2500

# %%
data.tail()
# Out:
#          Date    Open    High     Low   Close      Revenue    Volume  Price  \
# 88  4/30/2023  198500  211500  197400  200000  198543.6875  12759654  23000
# 89  5/31/2023  199800  209000  194000  206500  204996.3594  11549575  23000
# 90  6/30/2023  207500  210000  194000  196000  196000.0000  13134828  23000
# 91  7/31/2023  195200  199600  182600  185400  185400.0000   8869753  23000
# 92  8/29/2023       0       0       0  186700  186700.0000         0  23000
#
#     Profit
# 88    1500
# 89    6700
# 90  -11500
# 91   -9800
# 92  186700

# %% [markdown]
# # correlation

# %%
cor = data['Revenue'].corr(data['Volume'])
print(cor)
# Out:
# 0.1450624250397955

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
correlation_matrix = data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()


print("\nTask 5: Data Visualization")
# Visualization 1: Line plot showing the trend in sales over time
plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Revenue'], label='Revenue')
plt.xlabel("Date")
plt.ylabel("Revenue")
plt.title("Trend in Sales Over Time")
plt.legend()
plt.show()

# Visualization 2: Bar plot showing the total sales for each product category
plt.figure(figsize=(10, 6))
sns.barplot(x='High', y='Revenue', data=data, estimator=sum, ci=None)
plt.xlabel("Product Category")
plt.ylabel("Total Revenue")
plt.title("Total Sales for Each Product Category")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_2312\38882437.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()
# Task 5: Data Visualization
# C:\Users\admin\AppData\Local\Temp\ipykernel_2312\38882437.py:19: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='High', y='Revenue', data=data, estimator=sum, ci=None)
