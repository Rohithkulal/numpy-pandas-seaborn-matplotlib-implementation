# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv")

# %%
data
# Out:
#       id  gravity    ph  osmo  cond  urea  calc  target
# 0      0    1.013  6.19   443  14.8   124  1.45       0
# 1      1    1.025  5.40   703  23.6   394  4.18       0
# 2      2    1.009  6.13   371  24.5   159  9.04       0
# 3      3    1.021  4.91   442  20.8   398  6.63       1
# 4      4    1.021  5.53   874  17.8   385  2.21       1
# ..   ...      ...   ...   ...   ...   ...   ...     ...
# 409  409    1.011  5.21   527  21.4    75  1.53       0
# 410  410    1.024  5.53   577  19.7   224  0.77       0
# 411  411    1.018  6.28   455  22.2   270  7.68       1
# 412  412    1.008  7.12   325  12.6    75  1.03       1
# 413  413    1.011  6.13   364   9.9   159  0.27       0
#
# [414 rows x 8 columns]

# %%
data.describe()
# Out:
#                id     gravity          ph         osmo        cond  \
# count  414.000000  414.000000  414.000000   414.000000  414.000000
# mean   206.500000    1.017894    5.955459   651.545894   21.437923
# std    119.655756    0.006675    0.642260   234.676567    7.514750
# min      0.000000    1.005000    4.760000   187.000000    5.100000
# 25%    103.250000    1.012000    5.530000   455.250000   15.500000
# 50%    206.500000    1.018000    5.740000   679.500000   22.200000
# 75%    309.750000    1.022000    6.280000   840.000000   27.600000
# max    413.000000    1.040000    7.940000  1236.000000   38.000000
#
#              urea        calc      target
# count  414.000000  414.000000  414.000000
# mean   278.657005    4.114638    0.444444
# std    136.442249    3.217641    0.497505
# min     10.000000    0.170000    0.000000
# 25%    170.000000    1.450000    0.000000
# 50%    277.000000    3.130000    0.000000
# 75%    385.000000    6.630000    1.000000
# ...

# %%
data.head()
# Out:
#    id  gravity    ph  osmo  cond  urea  calc  target
# 0   0    1.013  6.19   443  14.8   124  1.45       0
# 1   1    1.025  5.40   703  23.6   394  4.18       0
# 2   2    1.009  6.13   371  24.5   159  9.04       0
# 3   3    1.021  4.91   442  20.8   398  6.63       1
# 4   4    1.021  5.53   874  17.8   385  2.21       1

# %%
data.tail()
# Out:
#       id  gravity    ph  osmo  cond  urea  calc  target
# 409  409    1.011  5.21   527  21.4    75  1.53       0
# 410  410    1.024  5.53   577  19.7   224  0.77       0
# 411  411    1.018  6.28   455  22.2   270  7.68       1
# 412  412    1.008  7.12   325  12.6    75  1.03       1
# 413  413    1.011  6.13   364   9.9   159  0.27       0

# %%
n_data = data.dropna()
print(n_data.to_string())
# Out:
#       id  gravity    ph  osmo  cond  urea   calc  target
# 0      0    1.013  6.19   443  14.8   124   1.45       0
# 1      1    1.025  5.40   703  23.6   394   4.18       0
# 2      2    1.009  6.13   371  24.5   159   9.04       0
# 3      3    1.021  4.91   442  20.8   398   6.63       1
# 4      4    1.021  5.53   874  17.8   385   2.21       1
# 5      5    1.025  6.90   947  28.4   395   2.64       1
# 6      6    1.008  5.09   371  15.5   159   2.17       1
# 7      7    1.015  5.53   450   8.1   170   1.16       0
# 8      8    1.025  7.38   736  25.3   418   1.52       0
# 9      9    1.017  6.61   527  20.0    75   4.49       1
# 10    10    1.017  6.81   680  25.7   282   0.17       1
# 11    11    1.009  6.37   364   8.8   159   1.22       0
# 12    12    1.017  6.79   541  20.0   187   6.96       1
# 13    13    1.021  6.56   703  22.2   418   4.18       1
# 14    14    1.007  7.01   516  20.0    72   1.22       0
# ...

# %%
data.fillna(120, inplace=True)

# %%
data["urea"].fillna(120, inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       414 non-null    int64
#  1   gravity  414 non-null    float64
#  2   ph       414 non-null    float64
#  3   osmo     414 non-null    int64
#  4   cond     414 non-null    float64
#  5   urea     414 non-null    int64
#  6   calc     414 non-null    float64
#  7   target   414 non-null    int64
# dtypes: float64(4), int64(4)
# memory usage: 26.0 KB

# %%
x = data["urea"].mean()
data["urea"].fillna(x, inplace = True)
print(x)
# Out:
# 278.65700483091786

# %%
data1 = pd.read_csv("f_data.csv")

# %%
data1
# Out:
#       Symbol                                   Name   Price  Change  \
# 0      BRK-B                Berkshire Hathaway Inc.  321.26   -1.38
# 1          V                              Visa Inc.  230.76   -0.25
# 2        JPM                   JPMorgan Chase & Co.  133.89   -2.16
# 3         MA                Mastercard Incorporated  380.21   -3.18
# 4     JPM-PD                   JPMorgan Chase & Co.   24.57   -0.08
# ...      ...                                    ...     ...     ...
# 1245  AIG-PA     American International Group, Inc.   24.59    0.02
# 1246    BBVA  Banco Bilbao Vizcaya Argentaria, S.A.    7.16    0.04
# 1247  MET-PA                          MetLife, Inc.   21.98    0.22
# 1248  MET-PE                          MetLife, Inc.   23.79    0.04
# 1249     TRV          The Travelers Companies, Inc.  181.84   -0.97
#
#      market cap  PE_ratio
# 0      709.361B       NaN
# 1      483.304B     30.81
# 2      392.325B      9.90
# 3      359.338B     37.85
# ...

# %%
data1.describe()
# Out:
#             Change     PE_ratio
# count  1250.000000  1235.000000
# mean      0.055432    21.220227
# std       1.454323    41.848345
# min      -3.180000     0.390000
# 25%      -0.220000     3.570000
# 50%      -0.010000     9.080000
# 75%       0.100000    20.370000
# max       8.970000   325.770000

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1250 entries, 0 to 1249
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Symbol      1250 non-null   object
#  1   Name        1250 non-null   object
#  2   Price       1250 non-null   object
#  3   Change      1250 non-null   float64
#  4   market cap  1250 non-null   object
#  5   PE_ratio    1235 non-null   float64
# dtypes: float64(2), object(4)
# memory usage: 58.7+ KB

# %%
data1.head()
# Out:
#    Symbol                     Name   Price  Change market cap  PE_ratio
# 0   BRK-B  Berkshire Hathaway Inc.  321.26   -1.38   709.361B       NaN
# 1       V                Visa Inc.  230.76   -0.25   483.304B     30.81
# 2     JPM     JPMorgan Chase & Co.  133.89   -2.16   392.325B      9.90
# 3      MA  Mastercard Incorporated  380.21   -3.18   359.338B     37.85
# 4  JPM-PD     JPMorgan Chase & Co.   24.57   -0.08   326.427B      1.82

# %%
data1.tail()
# Out:
#       Symbol                                   Name   Price  Change  \
# 1245  AIG-PA     American International Group, Inc.   24.59    0.02
# 1246    BBVA  Banco Bilbao Vizcaya Argentaria, S.A.    7.16    0.04
# 1247  MET-PA                          MetLife, Inc.   21.98    0.22
# 1248  MET-PE                          MetLife, Inc.   23.79    0.04
# 1249     TRV          The Travelers Companies, Inc.  181.84   -0.97
#
#      market cap  PE_ratio
# 1245    44.115B      2.15
# 1246    42.985B      5.97
# 1247    42.691B      2.82
# 1248    42.184B      3.05
# 1249     42.24B     15.50

# %%
n_data1 = data1.dropna()
print(n_data1.to_string())
# Out:
#        Symbol                                    Name     Price  Change market cap  PE_ratio
# 1           V                               Visa Inc.    230.76   -0.25   483.304B     30.81
# 2         JPM                    JPMorgan Chase & Co.    133.89   -2.16   392.325B      9.90
# 3          MA                 Mastercard Incorporated    380.21   -3.18   359.338B     37.85
# 4      JPM-PD                    JPMorgan Chase & Co.     24.57   -0.08   326.427B      1.82
# 5      JPM-PC                    JPMorgan Chase & Co.     25.02   -0.09   328.207B      1.86
# 6      BAC-PK             Bank of America Corporation     24.38   -0.04   244.596B      6.94
# 7      BAC-PL             Bank of America Corporation  1,144.76    0.79          0    325.77
# 8      BML-PG             Bank of America Corporation     20.02   -0.03    270.35B      5.70
# 9      BML-PH             Bank of America Corporation     19.90    0.05   269.812B      5.66
# ...

# %%
data1["market cap"].fillna(120.23, inplace = True)

# %%
data1.head(20)
# Out:
#     Symbol                         Name     Price  Change market cap  PE_ratio
# 0    BRK-B      Berkshire Hathaway Inc.    321.26   -1.38   709.361B       NaN
# 1        V                    Visa Inc.    230.76   -0.25   483.304B     30.81
# 2      JPM         JPMorgan Chase & Co.    133.89   -2.16   392.325B      9.90
# 3       MA      Mastercard Incorporated    380.21   -3.18   359.338B     37.85
# 4   JPM-PD         JPMorgan Chase & Co.     24.57   -0.08   326.427B      1.82
# 5   JPM-PC         JPMorgan Chase & Co.     25.02   -0.09   328.207B      1.86
# 6   BAC-PK  Bank of America Corporation     24.38   -0.04   244.596B      6.94
# 7   BAC-PL  Bank of America Corporation  1,144.76    0.79          0    325.77
# 8   BML-PG  Bank of America Corporation     20.02   -0.03    270.35B      5.70
# 9   BML-PH  Bank of America Corporation     19.90    0.05   269.812B      5.66
# 10     BAC  Bank of America Corporation     27.06   -0.33   215.526B      8.10
# ...

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 15, 7, 12, 8]

# Create a line plot
plt.plot(x, y,marker='o' ,color='blue', label='Data Points')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Sample Line Plot')
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 15, 7, 12, 8]

# Create a line plot
plt.plot(x, y,"k*", label='Data Points')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Sample Line Plot')
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 15, 7, 12, 8]

# Create a line plot
plt.bar(x, y ,color='blue', label='Data Points')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Bar graph Plot')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 15, 7, 12, 8]

# Create a line plot
plt.hist(x ,color='red', label='Data Points')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Histgram Plot')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 15, 7, 12, 8]

# Create a line plot
plt.scatter(x, y ,color='blue', label='Data Points')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scattering Plot')
plt.legend()

plt.show()

# %%
plt.figure(figsize=(20,5))
plt.plot([1,2,3,4],[2,4,6,8])
plt.show()

# %%
import numpy as np
x=np.arange(5)   # 0 1 2 3 4
y=x**3
plt.plot([1,2,3,4],"go",x,y,"r^")
plt.show()

# %%
from matplotlib import pyplot as plt
x= [ 2, 3, 4, 5, 6,7]
y= [2, 3, 4, 5, 6,7]
plt.plot(x,y)
plt.title("LINE GRAPH")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
x = [5,8,10]
y = [12,16,6]

x2 = [6,9,11]
y2 = [6,15,7]

plt.plot(x,y,'g',label='line one',linewidth = 5)
plt.plot(x2,y2,'c',label='line two',linewidth = 5)

plt.title('info')
plt.ylabel('y axis')
plt.xlabel('x axis')

plt.legend()
plt.grid(True,color = 'k')
plt.show()

# %% [markdown]
# # seaborn

# %%
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
taxis
